# %%
b1 = [[0., 6.26327, 12.4669, 18.6705, 24.8742, 31.0778, 37.2814, 43.4851, 
  49.6887, 55.8924, 62.096], [0., 5.22219, 10.877, 16.143, 25.6964, 
  37.9766, 54.26, 72.0991, 91.2866, 113.283, 136.589], [0., 5.19954, 
  11.051, 16.7526, 28.2577, 43.9997, 63.1306, 85.0658, 107.604, 
  134.614, 164.205]]

# %%
b10 = [[0., 6.26327, 12.4669, 18.6705, 24.8742, 31.0778, 37.2814, 43.4851, 
  49.6887, 55.8924, 62.096], [0., 4.93323, 10.4851, 16.1901, 24.3656, 
  33.066, 41.5621, 51.906, 58.7085, 71.3584, 85.7203], [0., 4.70892, 
  11.2638, 19.0153, 29.3214, 40.0988, 54.6953, 69.4073, 85.955, 
  106.146, 127.08]]

# %%
b100 = [[0., 6.26327, 12.4669, 18.6705, 24.8742, 31.0778, 37.2814, 43.4851, 
  49.6887, 55.8924, 62.096], [0., 4.64982, 7.59083, 11.7492, 16.4615, 
  18.0435, 23.4141, 27.6786, 37.2697, 41.2485, 42.9826], [0., 4.57905,
   8.77091, 10.126, 14.1915, 17.1086, 20.799, 26.8804, 29.072, 
  35.7711, 35.0978]]

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
Ts = np.arange(0, 11)

# %%
import numpy as np
plt.rcParams['text.usetex'] = False
def quad(a, b, c, x):
    return c + b*x + a*x**2
size=18
params = {'legend.fontsize': size*.75,
          'axes.labelsize': size,
          'axes.titlesize': size,
          'xtick.labelsize': size*0.75,
          'ytick.labelsize': size*0.75,
          'axes.titlepad': 25}
plt.rcParams.update(params)
for i in range(1):
    plt.plot(Ts, b1[i], label=f"2πT")
    a, b, c = np.polyfit(Ts, b1[i], 2)
    #plt.plot([quad(a, b, c, x) for x in Ts])
for i in range(1, 3):
    plt.plot(Ts, b1[i], label=f"π/{2**i}, B={1} tesla")

a, b, c = np.polyfit(Ts, b1[2], 2)
plt.plot([quad(a, b, c, x) for x in Ts], '--')
for i in range(1, 3):
    plt.plot(Ts, b10[i], label=f"π/{2**i}, B={10} tesla")
    a, b, c = np.polyfit(Ts, b10[i], 2)
    #plt.plot([quad(a, b, c, x) for x in Ts])
for i in range(1, 3):
    plt.plot(Ts, b100[i], label=f"π/{2**i}, B={10} tesla")
    a, b, c = np.polyfit(Ts, b100[i], 2)
    #plt.plot([quad(a, b, c, x) for x in Ts])
a, b, c = np.polyfit(Ts, b100[2], 2)
plt.plot([quad(a, b, c, x) for x in Ts], '--')

plt.legend()
plt.xlabel(r"T (sec)")
plt.ylabel(r"IQFI/ζ² (Hz$^{-1})$")
# Out:
# Text(0, 0.5, 'IQFI/ζ² (Hz$^{-1})$')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['text.usetex'] = True


t = np.linspace(0.0, 1.0, 100)
s = np.cos(4 * np.pi * t) + 2

fig, ax = plt.subplots(figsize=(6, 4), tight_layout=True)
ax.plot(t, s)

ax.set_xlabel(r'\textbf{time (s)}')
ax.set_ylabel('\\textit{Velocity (\N{DEGREE SIGN}/sec)}', fontsize=16)
ax.set_title(r'\TeX\ is Number $\displaystyle\sum_{n=1}^\infty'
             r'\frac{-e^{i\pi}}{2^n}$!', fontsize=16, color='r')
# Out:
# Text(0.5, 1.0, '\\TeX\\ is Number $\\displaystyle\\sum_{n=1}^\\infty\\frac{-e^{i\\pi}}{2^n}$!')
